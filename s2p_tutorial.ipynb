# %% [markdown]
# ![NINC_DBC_DMCBH_logos.jpg](attachment:NINC_DBC_DMCBH_logos.jpg)
#
# These tutorial notebooks were developed at the Djavad Mowafaghian Centre for Brain Health by the NINC/UBC Brain Circuits team.  If you find the tutorials useful you can acknowledge us with the following statement:
#
# <em>"This work was supported by resources made available through the Dynamic Brain Circuits cluster and the NeuroImaging and NeuroComputation Core at the UBC Djavad Mowafaghian Centre for Brain Health (RRID:SCR_019086)."</em>
#
# If you use the packages in your research, please cite the originators as per their documentation.

# %% [markdown]
# # Suite2p Tutorial
#
# We would like to install the GUI version of suite2p for this workshop.
#
# If the code block below is showing warnings, check that you have the correct kernel running.
#
# >To view your current kernel or change kernels, go to the top menu bar and click Kernel > Change kernel In the dropdown menu, you should be selecting Python[conda env:DEEPLABCUT] or Python[conda env:DEEPLABCUT_M1], depending on which .yaml file you used.

# %%
import suite2p
from pathlib import Path #package for managing paths

# %% [markdown]
# We will now be settings the file paths of your data, as well as where your results will go:

# %%
data_path = Path(Path.cwd(), "my_files", "data")
save_path = Path(Path.cwd(), "my_files", "working_dir")

# %% [markdown]
# Then also set some variable values below before running the next block of code:

# %%
nplanes = ""
nchannels = ""
tau = "" 
fs = ""
